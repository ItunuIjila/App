# %% [markdown]
# ### Importing Libraries

# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("mentalhealth.json").read()
intents = json.loads(data_file)

# %% [markdown]
# ### Data Pre-Processing

# %%
# preprocessing the json data
# tokenization
nltk.download('punkt')
nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# lemmatize, lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('words.pkl','wb')) 
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 22 documents
# 10 classes ['affects_whom', 'definition', 'find_help', 'professional_types', 'recover', 'right_professional', 'steps', 'treatement_options', 'treatment_tips', 'what_causes']
# 64 unique lemmatized words ['a', 'affect', 'affected', 'appears', 'are', 'available', 'be', 'become', 'begin', 'between', 'by', 'can', 'cause', 'describe', 'difference', 'different', 'doe', 'find', 'followed', 'for', 'from', 'get', 'have', 'health', 'how', 'i', 'if', 'ill', 'illness', 'in', 'incase', 'involved', 'is', 'it', 'keep', 'know', 'lead', 'mean', 'mental', 'mentall', 'mentally', 'mind', 'myself', 'of', 'one', 'option', 'people', 'possible', 'present', 'professional', 'recover', 'right', 'should', 'someone', 'step', 'such', 'symptom', 'the', 'to', 'treatment', 'type', 'what', 'who', 'with']

# %% [markdown]
# ### Creating Training Data

# %%
# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# ### Creating NN Model

# %%
# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 4ms/step - loss: 2.3627 - accuracy: 0.0909
# Epoch 2/200
# 5/5 [==============================] - 0s 5ms/step - loss: 2.3391 - accuracy: 0.0909
# Epoch 3/200
# 5/5 [==============================] - 0s 5ms/step - loss: 2.2439 - accuracy: 0.2727
# Epoch 4/200
# 5/5 [==============================] - 0s 8ms/step - loss: 2.0694 - accuracy: 0.2727
# Epoch 5/200
# 5/5 [==============================] - 0s 5ms/step - loss: 2.0783 - accuracy: 0.2273
# Epoch 6/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.8996 - accuracy: 0.5455
# Epoch 7/200
# 5/5 [==============================] - 0s 8ms/step - loss: 1.9020 - accuracy: 0.2273
# Epoch 8/200
# 5/5 [==============================] - 0s 7ms/step - loss: 1.7916 - accuracy: 0.3636
# Epoch 9/200
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5301 - accuracy: 0.5455
# Epoch 10/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6171 - accuracy: 0.4545
# Epoch 11/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.5604 - accuracy: 0.5455
# Epoch 12/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.3928 - accuracy: 0.5000
# Epoch 13/200
# 5/5 [==============================] - 0s 8ms/step - loss: 1.3496 - accuracy: 0.5909
# Epoch 14/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1.2720 - accuracy: 0.6818
# Epoch 15/200
# 5/5 [==============================] - 0s 6ms/step - loss: 1.0042 - accuracy: 0.7273
# Epoch 16/200
# 5/5 [==============================] - 0s 7ms/step - loss: 1.1161 - accuracy: 0.6364
# Epoch 17/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9987 - accuracy: 0.8182
# Epoch 18/200
# 5/5 [==============================] - 0s 5ms/step - loss: 1.1674 - accuracy: 0.5000
# Epoch 19/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8729 - accuracy: 0.7273
# Epoch 20/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9810 - accuracy: 0.5909
# Epoch 21/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.9058 - accuracy: 0.6818
# Epoch 22/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.8847 - accuracy: 0.6364
# Epoch 23/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.8153 - accuracy: 0.7727
# Epoch 24/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.5492 - accuracy: 0.9091
# Epoch 25/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6940 - accuracy: 0.6818
# Epoch 26/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4152 - accuracy: 1.0000
# Epoch 27/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.8208 - accuracy: 0.8636
# Epoch 28/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2685 - accuracy: 0.9545
# Epoch 29/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6266 - accuracy: 0.8636
# Epoch 30/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.5781 - accuracy: 0.8636
# Epoch 31/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.7081 - accuracy: 0.7273
# Epoch 32/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3173 - accuracy: 0.9091
# Epoch 33/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3744 - accuracy: 0.9091
# Epoch 34/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3963 - accuracy: 0.8182
# Epoch 35/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3308 - accuracy: 0.8636
# Epoch 36/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5555 - accuracy: 0.7727
# Epoch 37/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2634 - accuracy: 0.9545
# Epoch 38/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2208 - accuracy: 0.9091
# Epoch 39/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1551 - accuracy: 0.9545
# Epoch 40/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3822 - accuracy: 0.8636
# Epoch 41/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.6601 - accuracy: 0.7273
# Epoch 42/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6271 - accuracy: 0.7273
# Epoch 43/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1454 - accuracy: 1.0000
# Epoch 44/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.4575 - accuracy: 0.8182
# Epoch 45/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3163 - accuracy: 0.9091
# Epoch 46/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1872 - accuracy: 0.9545
# Epoch 47/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5129 - accuracy: 0.8182
# Epoch 48/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2080 - accuracy: 0.9091
# Epoch 49/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.5292 - accuracy: 0.9091
# Epoch 50/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3240 - accuracy: 0.9091
# Epoch 51/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2940 - accuracy: 0.8636
# Epoch 52/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2109 - accuracy: 0.9091
# Epoch 53/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2649 - accuracy: 0.9091
# Epoch 54/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 1.0000
# Epoch 55/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9545
# Epoch 56/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0995 - accuracy: 1.0000
# Epoch 57/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2013 - accuracy: 0.9545
# Epoch 58/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1729 - accuracy: 0.9091
# Epoch 59/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3704 - accuracy: 0.8182
# Epoch 60/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1801 - accuracy: 1.0000
# Epoch 61/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9545
# Epoch 62/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2343 - accuracy: 1.0000
# Epoch 63/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1267 - accuracy: 0.9545
# Epoch 64/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1468 - accuracy: 0.9545
# Epoch 65/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1642 - accuracy: 0.9091
# Epoch 66/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2247 - accuracy: 0.9545
# Epoch 67/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1657 - accuracy: 1.0000
# Epoch 68/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9545
# Epoch 69/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.9545
# Epoch 70/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9545
# Epoch 71/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9545
# Epoch 72/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1881 - accuracy: 1.0000
# Epoch 73/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0749 - accuracy: 0.9545
# Epoch 74/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0925 - accuracy: 0.9545
# Epoch 75/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2027 - accuracy: 0.9091
# Epoch 76/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1577 - accuracy: 0.9545
# Epoch 77/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.2452 - accuracy: 0.9545
# Epoch 78/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1068 - accuracy: 0.9545
# Epoch 79/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 80/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 1.0000
# Epoch 81/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1884 - accuracy: 0.9545
# Epoch 82/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 83/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1353 - accuracy: 1.0000
# Epoch 84/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9545
# Epoch 85/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9545
# Epoch 86/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1496 - accuracy: 0.9545
# Epoch 87/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0903 - accuracy: 0.9545
# Epoch 88/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 1.0000
# Epoch 89/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.9545
# Epoch 90/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1373 - accuracy: 0.9545
# Epoch 91/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1047 - accuracy: 0.9545
# Epoch 92/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 1.0000
# Epoch 93/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9545
# Epoch 94/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 95/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2050 - accuracy: 0.9091
# Epoch 96/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1728 - accuracy: 0.9545
# Epoch 97/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 98/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.9545
# Epoch 99/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0822 - accuracy: 0.9545
# Epoch 100/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1184 - accuracy: 1.0000
# Epoch 101/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1324 - accuracy: 1.0000
# Epoch 102/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 103/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 104/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 105/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1383 - accuracy: 0.9545
# Epoch 106/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 107/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9545
# Epoch 108/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.9545
# Epoch 109/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 110/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 111/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1119 - accuracy: 0.9545
# Epoch 112/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 113/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9545
# Epoch 114/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 115/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 116/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 1.0000
# Epoch 117/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 118/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9545
# Epoch 119/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1482 - accuracy: 0.9545
# Epoch 120/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 1.0000
# Epoch 121/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9545
# Epoch 122/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 1.0000
# Epoch 123/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 124/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 125/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 126/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 127/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 128/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 129/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 130/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0798 - accuracy: 0.9545
# Epoch 131/200
# 5/5 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 1.00 - 0s 4ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 132/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 133/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 134/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 135/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0798 - accuracy: 0.9545
# Epoch 136/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0847 - accuracy: 1.0000
# Epoch 137/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 138/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 1.0000
# Epoch 139/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0816 - accuracy: 0.9545
# Epoch 140/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 141/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 142/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 143/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 144/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 145/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0583 - accuracy: 1.0000
# Epoch 146/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2563 - accuracy: 0.9545
# Epoch 147/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 148/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 149/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 150/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 151/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 152/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 153/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 154/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 155/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 156/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 157/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 158/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 159/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1522 - accuracy: 0.9545
# Epoch 160/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0987 - accuracy: 0.9545
# Epoch 161/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 0.9545
# Epoch 162/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 163/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 1.0000
# Epoch 164/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 165/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 166/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1352 - accuracy: 0.9545
# Epoch 167/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 168/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 169/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0374 - accuracy: 1.0000
# Epoch 170/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 171/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 172/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 173/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 174/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 175/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 176/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0838 - accuracy: 0.9545
# Epoch 177/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9545
# Epoch 178/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1124 - accuracy: 0.9091
# Epoch 179/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 180/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 181/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9545
# Epoch 182/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 183/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 184/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 185/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 186/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.1341 - accuracy: 1.0000
# Epoch 187/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 188/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9545
# Epoch 189/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 190/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 191/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 192/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 193/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0772 - accuracy: 0.9545
# Epoch 194/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 195/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 196/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 197/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 198/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 199/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 200/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0354 - accuracy: 1.0000
#
#
# **************************************************
#
# Model Created Successfully!

# %% [raw]
# The accuracy of the model is 99.22 % which is quite impressive.
#
# In the further steps, we will import all the libraries and Train_Bot json data and use the pickled model for the prediction of responses.

# %% [markdown]
# ### Repeating all the above steps and using the pickled model for the prediction of responses

# %%
# load the saved model file
model = load_model('chatbot.h5')
intents = json.loads(open("mentalhealth.json").read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):

    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    
    # stem each word - create short form for word
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words


# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):

    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)

    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
               
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
   
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    error = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>error]
    
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
# function to get the response from the model

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

# function to predict the class and get the response

def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
# function to start the chat bot which will continue till the user type 'end'

def start_chat():
    print("Bot: This is Sophie! Your Personal Assistant.\n\n")
    while True:
        inp = str(input()).lower()
        if inp.lower()=="end":
            break
        if inp.lower()== '' or inp.lower()== '*':
            print('Please re-phrase your query!')
            print("-"*50)
        else:
            print(f"Bot: {chatbot_response(inp)}"+'\n')
            print("-"*50)

# %% [markdown]
# ## Chatting with BOT using the Command Line Option

# %%
# start the chat bot
start_chat()
# Out:
# Bot: This is Sophie! Your Personal Assistant.

# %% [markdown]
# ## Chatting with BOT using the Tkinter App
#
# #### **For running the Tkinter GUI you have to download this notebook in ipynb format and run using jupyter notebook in your local machine/pc because in google colab, you cannot run Tkinter apps.**

# %%
import random
import tkinter as tk
from tkinter import *

root=tk.Tk()
filename="Chat Bot"
root.title(f"Chat Bot")
root.geometry('500x400')
root.resizable(False, False)
message=tk.StringVar()

chat_win=Frame(root,bd=1,bg='white',width=50,height=8)
chat_win.place(x=6,y=6,height=300,width=488)

textcon=tk.Text(chat_win,bd=1,bg='white',width=50,height=8)
textcon.pack(fill="both",expand=True)

mes_win=Entry(root,width=30,xscrollcommand=True,textvariable=message)
mes_win.place(x=6,y=310,height=60,width=380)
mes_win.focus()

textcon.config(fg='black')
textcon.tag_config('usr',foreground='black')
textcon.insert(END,"Bot: This is Sophie! Your Personal Assistant.\n\n")
mssg=mes_win.get()

exit_list = ['exit','break','quit','see you later','chat with you later','end the chat','bye','ok bye']

def greet_res(text):
    text=text.lower()
    bot_greet=['hi','hello','hola','hey','howdy']
    usr_greet=['hi','hey','hello','hola','greetings','wassup','whats up']
    for word in text.split():
        if word in usr_greet:
            return random.choice(bot_greet)

def send_msz(event=None):
    usr_input = message.get()
    usr_input = usr_input.lower()
    textcon.insert(END, f'You: {usr_input}'+'\n','usr')
    if usr_input in exit_list:
        textcon.config(fg='black')
        textcon.insert(END,"Bot: Ok bye! Chat with you later\n")
        return root.destroy()
    else:
        textcon.config(fg='black')
        if greet_res(usr_input) != None:
            lab=f"Bot: {greet_res(usr_input)}"+'\n'
            textcon.insert(END,lab)
            mes_win.delete(0,END)
        else:
            lab = f"Bot: {chatbot_response(usr_input)}"+'\n'
            textcon.insert(END,lab)
            mes_win.delete(0,END)

button_send=Button(root,text='Send',bg='dark green',activebackground='grey',command=send_msz,width=12,height=5,font=('Arial'))
button_send.place(x=376,y=310,height=60,width=110)
root.bind('<Return>', send_msz,button_send)
root.mainloop()

# %% [markdown]
# ### END
